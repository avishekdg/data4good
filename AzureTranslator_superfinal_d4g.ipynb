# %%
# Import the required modules
import json
import csv
import requests
import time
from azure.core.credentials import AzureKeyCredential
from azure.ai.textanalytics import TextAnalyticsClient
from azure.ai.textanalytics import TextAnalyticsApiVersion
from azure.core.exceptions import HttpResponseError

# Define the Azure Text Analytics and Translator credentials
text_analytics_key = "0a4065d87f7a453498faa85ad8c47bf0"
text_analytics_endpoint = "https://azureapi.cognitiveservices.azure.com/"
translator_key = "600a4d74fd7c4962a6111fa03c4d4a7e"
translator_endpoint = "https://api.cognitive.microsofttranslator.com/"

# Create the Text Analytics and Translator clients
text_analytics_client = TextAnalyticsClient(
    endpoint=text_analytics_endpoint,
    credential=AzureKeyCredential(text_analytics_key),
    #api_version=TextAnalyticsApiVersion.V3_0_0 # Use the latest preview version for Text Analytics for health
)
translator_client = requests.Session()
translator_client.headers.update({
    'Ocp-Apim-Subscription-Key': translator_key,
    'Ocp-Apim-Subscription-Region': "eastus2",
    'Content-type': 'application/json'
})

# Define the input and output files
input_file = "transcripts.json"
output_file = "output_final.csv"

# Define the rate limit for the free tier (5 requests per second)
rate_limit = 5

# Define a helper function to translate a text to English
def translate_to_english(text):
    # Construct the request body
    body = [{
        'text': text
    }]
    # Send the request to the Translator service
    response = translator_client.post(translator_endpoint + '/translate?api-version=3.0&to=en', json=body)
    # Parse the response
    result = response.json()
    # Return the translated text
    return result[0]['translations'][0]['text']

# Open the input file and load the JSON data
with open(input_file, 'r') as f:
    data = json.load(f)

# Open the output file and create a CSV writer
with open(output_file, 'w', encoding='utf-8') as f:
    writer = csv.writer(f)
    # Write the header row
    writer.writerow(['id', 'text', 'language', 'key_phrases'])

    # Loop through the data items
    for id, text in data.items():
        # Detect the language of the text
        try:
            response = text_analytics_client.detect_language(documents=[text])
            language = response[0].primary_language.name
        except HttpResponseError as e:
            print(f'Error detecting language for id {id}: {e}')
            language = 'Unknown'

        # If the language is not English, translate the text to English
        if language != 'English':
            text = translate_to_english(text)

        # Extract the key phrases from the text
        try:
            response = text_analytics_client.extract_key_phrases(documents=[text])
            key_phrases = ', '.join(response[0].key_phrases)
        except HttpResponseError as e:
            print(f'Error extracting key phrases for id {id}: {e}')
            key_phrases = ''

        # Write the output row
        writer.writerow([id, text, language, key_phrases])

        # Wait for 1/rate_limit seconds to avoid exceeding the free tier limit
        time.sleep(1/rate_limit)
# Out:
# Error detecting language for id 521: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 521: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 355: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 355: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3042: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3042: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3707: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3707: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1111: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1111: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4907: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4907: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4718: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4718: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2426: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2426: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 870: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 870: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1951: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1951: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4864: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4864: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4349: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4349: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1323: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1323: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3204: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3204: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2017: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2017: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 915: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 915: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1303: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1303: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3262: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3262: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3356: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3356: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2179: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2179: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 440: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 440: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4106: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4106: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4383: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4383: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 642: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 642: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2087: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2087: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4693: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4693: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3030: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3030: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 856: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 856: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4333: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4333: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2781: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2781: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4613: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4613: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3061: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3061: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2929: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2929: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3862: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3862: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2462: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2462: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 913: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 913: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4352: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4352: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4472: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4472: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2873: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2873: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1186: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1186: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 907: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 907: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 327: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 327: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1992: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1992: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4474: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4474: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3821: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3821: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2067: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2067: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1110: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1110: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 488: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 488: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 75: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 75: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 29: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 29: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 401: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 401: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4050: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4050: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1741: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1741: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1634: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1634: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3942: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3942: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3043: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3043: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 228: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 228: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1187: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1187: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3379: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3379: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 588: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 588: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4155: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4155: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2305: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2305: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3972: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3972: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2418: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2418: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4141: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4141: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3281: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3281: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1906: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1906: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 1301: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 1301: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2356: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2356: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3344: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3344: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 2048: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 2048: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 3943: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 3943: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 4621: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 4621: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 300: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error extracting key phrases for id 300: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Error detecting language for id 133: (403) Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# Code: 403
# Message: Out of call volume quota for TextAnalytics F0 pricing tier. Please retry after 9 days. To increase your call volume switch to a paid tier.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[3], line 72
#      70 # If the language is not English, translate the text to English
#      71 if language != 'English':
# ---> 72     text = translate_to_english(text)
#      74 # Extract the key phrases from the text
#      75 try:
#
# Cell In[3], line 48, in translate_to_english(text)
#      46 result = response.json()
#      47 # Return the translated text
# ---> 48 return result[0]['translations'][0]['text']
#
# KeyError: 0
